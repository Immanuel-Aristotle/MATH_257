# %% [markdown]
# In addition to the discrete cosine transform seen in Lesson 6, the singular value decomposition can be used to lossily compress images. By decomposing an image and discarding its least significant components, we can significantly reduce the file size.
#
# You are given the test image altgeld as a 2d NumPy array representing the image contents. You should first use numpy.linalg.svd() to decompose the image into the
# 𝑈
# ,
# 𝛴
# , and
# 𝑉
# 𝑇
#  matrices as in Lesson 10. Pass the argument full_matrices=False to compute the reduced SVD.
#
# Presume that we want to compress the image while retaining at least
# 59
# %
#  of the information. Determine the minimum number of component layers needed such that we have
# 59
# %
#  of the original image's quality. Formally, find the necessary layer count
# 𝑖
#  such that:
# ∑
# 𝑗
# =
# 0
# 𝑖
# 𝜎
# 𝑗
# ∑
# 𝑘
# =
# 0
# 𝑛
# 𝜎
# 𝑘
# ≥
# 59
# %
# where
# 𝑛
#  is the index of the last component layer.
# Save this zero-indexed minimum number of layers as num_layers.
#
# Finally, use this determined value of
# 𝑖
#  to create a low-rank approximation of the original altgeld image. Save this as altgeld_compressed. The layer indexed by num_layers should be included; for example, if num_layers is 2, you should include layers 0, 1, and 2.
#
# Some additional food for thought: if we create the low-rank approximation itself, are we actually saving storage space? What if we were to save the SVD components instead of the image? You don't need to answer this, but just think about how it would be beneficial.
#
# The setup code gives the following variables:
#
# Name	Type	Description
# altgeld	numpy array	Image to compress
#
# Your code snippet should define the following variables:
#
# Name	Type	Description
# num_layers	int	Highest index of layers needed to store desired quality
# altgeld_compressed	2d NumPy array	Low-rank approximation of the Altgeld image
